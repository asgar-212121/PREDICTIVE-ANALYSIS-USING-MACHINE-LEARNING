# %% [markdown]
# ##Task 2- PREDICTIVE ANALYSIS USING MACHINE LEARNING

# %%
pip install pandas numpy scikit-learn matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
    # ... your code using scikit-learn ...

# %% [markdown]
# ##Dataset Load

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv") # Update the path to point to the actual CSV file within the 'sample_data' directory.
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ##Data Cleaning & Encoding

# %%
print(df.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Assuming 'housing_median_age' is a column you want to encode:
# Replace 'housing_median_age' with the actual column name you want to encode.
df['housing_median_age_encoded'] = le.fit_transform(df['housing_median_age'])
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  \
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
#    housing_median_age_encoded
# 0                          14
# 1                          18
# 2                          16
# 3                          13
# ...

# %% [markdown]
# ##Train a Simple Model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 89816.4168199644

# %% [markdown]
# ##Predict New Salary

# %%
new_employee = [[5, 1]]  # 5 years experience, Master degree
predicted_salary = model.predict(new_employee)
print(f"Predicted Salary: {predicted_salary[0]}")
# Out:
# Predicted Salary: 141457.9767100113
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##Data Visualization

# %%
# Make sure 'Experience (Years)' is the correct column name
# ... or replace it with the actual name
# ... in the california_housing_train.csv dataset
# ... like 'housing_median_age' or 'total_rooms'

plt.figure(figsize=(8,5))

# Example: if your column name is 'housing_median_age' instead of 'Experience (Years)'
sns.scatterplot(x=df['housing_median_age'], y=df['median_house_value'], hue=df['total_rooms'])
# replace 'total_rooms' with another column that is relevant

plt.xlabel("housing_median_age") # Update the x-axis label accordingly
plt.ylabel("median_house_value") # Update the y-axis label accordingly
plt.title("median_house_value Prediction Based on housing_median_age & Education")
plt.show()
